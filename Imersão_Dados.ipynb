# %% [markdown]
# <a href="https://colab.research.google.com/github/ezkias/imersao-dados/blob/main/Imers%C3%A3o_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Imersão Dados 3**
#
# ---
# Autor: [*Ezequias Araújo de Sousa*](https://https://www.linkedin.com/in/ezkias/)

# %% [markdown]
# # **Aula 1 - Python, Pandas e Pharmacia**
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

#IMPORTAR OS DADOS ZIPADOS
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados['tratamento'].value_counts().plot.bar()

font = {'family':'serif','size':15}
plt.title('Tratamento', fontdict=font)
plt.xlabel('Tipo de tratamento', fontdict=font)
plt.ylabel('Quantidade administrada', fontdict=font)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# ## **Desafios da Aula 1**
#
#
# ---

# %% [markdown]
# ###**Desafio 01:** Investigar por que a classe tratamento é tão desbalanceada.

# %% [markdown]
# Levando em consideração a coluna droga, podemos perceber que a analise é feita com a administração de varias drogas e apenas um controle. Pra chegar a essa conclusão basta...

# %%
#Analisar os valores com_controle
controle = dados.query('tratamento == "com_controle"')
controle
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 153840764       1
# 7226e2204       1
# 89ced6383       1
# 6bb340664       1
# ed81f4046       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# E perceber que apenas a droga cacb2b860 fez parte do tratamento com_controle. Sabendo disso, concluimos que devido ao fato de que foi-se utilizado varias drogas mas apenas um controle, o número de experimentos controle pode ser menor.

# %% [markdown]
# ###**Desafio 02:** Plotar as 5 últimas linhas da tabela.

# %%
dados.tail() #Desafio 02
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###**Desafio 03:** Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True) #desafio 3
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ###**Desafio 04:** Quantos tipos de drogas foram investigados.

# %%
len(dados['droga'].unique()) #desafio 4
# Out:
# 3289

# %% [markdown]
# **Resposta:** Foram utilizadas 3288 drogas, já que uma delas foi utilizada como controle.

# %% [markdown]
# ###**Desafio 05:** Procurar na documentação do pandas o método query.

# %%
#Filtando o valor com_controle da coluna tratamento com a função query
controle = dados.query('tratamento == "com_controle"')
controle
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# ###**Desafio 06:** Colocar titulo no gráfico, label... Deixar bonitão.

# %%
dados['tratamento'].value_counts().plot.bar()

font = {'family':'serif','size':15}
plt.title('Tratamento', fontdict=font)
plt.xlabel('Tipo de tratamento', fontdict=font)
plt.ylabel('Quantidade administrada', fontdict=font)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
dados['tempo'].value_counts().sort_index().plot.bar(0)

font = {'family':'serif','color':'White','size':15}
plt.title('Tempo', fontdict=font)
plt.xlabel('Tempo da análise (horas)', fontdict=font)
plt.ylabel('Amostras análisadas', fontdict=font)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# ###**Desafio 07:** Renomear as colunas tirando o hífen.

# %%
dados.columns = [i.replace('-', '') for i in dados.columns]
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
mapa= {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %% [markdown]
# ###**Desafio 08:** Resumo do que eu aprendi com os dados.

# %% [markdown]
# Com os dados analisados nas atividades de hoje aprendi um pouco mais como o processo de analise de drogras é feito, além de apreder a tratar esses dados da forma correta.
# Aprendi também a gerar e manipular graficos (de pizza e de barras), utilizar algumas funções da biblioteca pandas e trabalhar melhor com o jupyter (no caso o Google Colabs).

# %%
dados['tempo'].value_counts().sort_index().plot.bar(0)

font = {'family':'serif','size':15}
plt.title('Tempo', fontdict=font)
plt.xlabel('Tempo da análise (horas)', fontdict=font)
plt.ylabel('Amostras análisadas', fontdict=font)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# # **Aula 2 - Estatísticas, dados e distribuições**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins=100)
plt.show()

# %%
dados['g19'].hist(bins=100)
plt.show()

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[{'g0', 'g1'}]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=30)
plt.show()

# %%
dados.loc[:, 'g0':'g771'].describe().T['min'].hist(bins=30)
plt.show()

# %%
dados.loc[:, 'g0':'g771'].describe().T['max'].hist(bins=30)
plt.show()

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)
plt.show()

# %%
sns.boxplot(y='g0', x='tratamento', data=dados)
plt.figure(figsize=(8,6))
plt.show()

# %% [markdown]
# ## **Desafios da Aula 2**

# %% [markdown]
# ### **Desafio 01:** Ordenar o gráfico countplot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = dados.query('composto in @cod_compostos')['composto'].value_counts().index)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# ### **Desafio 02:** Melhorar a visualização alterando tamanho da fonte...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order = dados.query('composto in @cod_compostos')['composto'].value_counts().index)
ax.set_title('Top 5 compostos', weight='bold', fontdict={'fontsize':15})
ax.set_xlabel('Compostos', weight='bold', fontdict={'fontsize':12})
ax.set_ylabel('Quantidade de compostos', weight='bold', fontdict={'fontsize':12})
plt.show()

# %% [markdown]
# ### **Desafio 03:** Plotar os histogramas com seaborn.

# %%
ax = sns.histplot(x='g0', data=dados, bins=100, kde=True)
ax.set_title('Histograma da coluna g0', weight='bold', fontdict={'fontsize': 15})
ax.set_xlabel('Intervalo', weight='bold', fontdict={'fontsize': 12})
ax.set_ylabel('Contagem', weight='bold', fontdict={'fontsize': 12})
plt.show()

# %%
ax = sns.histplot(x=dados.loc[:, 'g0':'g771'].describe().T['mean'], data=dados, bins=30)
ax.set_title("Histograma dos valores médios das colunas G's", weight='bold', fontdict={'fontsize': 12})
ax.set_xlabel('Intervalo', weight='bold', fontdict={'fontsize': 10})
ax.set_ylabel('Contagem', weight='bold', fontdict={'fontsize': 10})
plt.show()

# %%
ax = sns.histplot(x=dados.loc[:, 'g0':'g771'].describe().T['min'], data=dados, bins=30)
ax.set_title("Histograma dos valores mínimos das colunas G's", weight='bold', fontdict={'fontsize': 12})
ax.set_xlabel('Intervalo', weight='bold', fontdict={'fontsize': 10})
ax.set_ylabel('Contagem', weight='bold', fontdict={'fontsize': 10})
plt.show()

# %%
ax = sns.histplot(x=dados.loc[:, 'g0':'g771'].describe().T['max'], data=dados, bins=30)
ax.set_title("Histograma dos valores máximos das colunas G's", weight='bold', fontdict={'fontsize': 12})
ax.set_xlabel('Intervalo', weight='bold', fontdict={'fontsize': 10})
ax.set_ylabel('Contagem', weight='bold', fontdict={'fontsize': 10})
plt.show()

# %%
ax = sns.histplot(x=dados.loc[:, 'c0':'c99'].describe().T['mean'], data=dados, bins=30)
ax.set_title("Histograma dos valores médios das colunas C's", weight='bold', fontdict={'fontsize': 12})
ax.set_xlabel('Intervalo', weight='bold', fontdict={'fontsize': 10})
ax.set_ylabel('Contagem', weight='bold', fontdict={'fontsize': 10})
plt.show()

# %% [markdown]
# ### **Desafio 04:** Estudar sobre as estatísticas retornadas no .describre()

# %% [markdown]
# A função .describe() gera estatísticas descritivas. É usada para visualizar alguns detalhes estatísticos básicos como média, mediana, mínimo, máximo, percentis, contagem de um quadro de dados ou série de valores numéricos.

# %% [markdown]
# ### **Desafio 05:** Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# ### **Desafio 06:** Fazer outras análises com o boxplot e até com o histograma.

# %%
max = dados.loc[:, 'g0':'g771'].describe().T['max']
min = dados.loc[:, 'g0':'g771'].describe().T['min']
sns.histplot(data=min, color = 'r')
sns.histplot(data=max, color = 'b')
plt.show()

# %%
sns.boxplot(y='g0', x='tratamento', hue='tempo', data=dados)
plt.figure(figsize=(8,6))

sns.despine(offset=10, trim=True)

# %% [markdown]
# ### **Desafio 07:** Resumo do que eu aprendi com os dados.

# %% [markdown]
# Hoje consegui aprender como importar e integrar a biblioteca seaborn no meu notebook para que com a mesma eu possa fazer uma analise mais detalhada do dataframe.

# %% [markdown]
# # **Aula 3 - Correlações e causaliade**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0', y='g3', data=dados)
plt.show()

# %%
sns.scatterplot(x='g0', y='g8', data=dados)
plt.show()

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'})

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g0':'g50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c0':'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## **Desafios Aula 3**

# %% [markdown]
# ### **Desafio 01:** Criar tabelas de frequência com pandas.groupbby()

# %%
dados.groupby([dados['dose'],dados['tempo'], dados['tratamento']],sort = True).mean()
# Out:
#                                g0        g1  ...       c98       c99
# dose tempo tratamento                        ...
# D1   24    com_controle -0.251760 -0.453322  ...  0.350566  0.342308
#            com_droga     0.367996 -0.170839  ... -0.340809 -0.216371
#      48    com_controle -0.122773 -0.453638  ...  0.408657  0.450673
#            com_droga     0.412469 -0.142581  ... -0.634006 -0.389838
#      72    com_controle -0.295271 -0.669059  ...  0.379652  0.319684
#            com_droga     0.286250 -0.127878  ... -0.835132 -0.588545
# D2   24    com_controle  0.010754 -0.229451  ...  0.134107  0.112021
#            com_droga     0.115253 -0.081764  ... -0.254499 -0.187848
#      48    com_controle  0.013174  0.001737  ...  0.232461  0.169539
#            com_droga     0.214480 -0.001143  ... -0.485368 -0.317882
#      72    com_controle  0.070250  0.133537  ...  0.200942  0.165440
#            com_droga     0.253439  0.052840  ... -0.644784 -0.391018
#
# ...

# %% [markdown]
# ### **Desafio 02:** Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ### **Desafio 03:** Explorar outros agregadores.

# %%
pd.crosstab(dados['dose'], dados['tratamento'], values=dados['g0'], normalize='columns', aggfunc='sum')
# Out:
# tratamento  com_controle  com_droga
# dose
# D1              1.159743   0.657025
# D2             -0.159743   0.342975

# %%
pd.crosstab(dados['dose'], dados['tratamento'], values=dados['g0'], normalize='columns', aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose
# D1              0.402704   0.495747
# D2              0.597296   0.504253

# %% [markdown]
# ### **Desafio 04:** Explorar o melt.

# %%
gmelt = pd.melt(dados,['dose','tempo'],['tratamento'])
gmelt.pivot_table(index=['dose','tempo','value'], aggfunc='size').unstack(2)
# Out:
# value       com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# ### **Desafio 05:** Calcular e analisar a correlação entre os G e C. Refletir sore os efeitos biológicos.

# %%
g = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'g0':'g50'])
c = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'c0':'c50'])
g_c = pd.concat([g, c], axis =1, join = 'inner')
g_c = g_c.corr()
g_c_corr = g_c.loc['c0':'c50','g0':'g50']
g_c_corr
# Out:
#            g0        g1        g2  ...       g48       g49       g50
# c0  -0.623017  0.088438 -0.120350  ... -0.091325 -0.524907  0.627665
# c1  -0.634405  0.080976 -0.132486  ... -0.168464 -0.455220  0.716400
# c2  -0.647538  0.075728 -0.127077  ... -0.186027 -0.483289  0.732057
# c3  -0.610505  0.126183 -0.118838  ... -0.130319 -0.515533  0.660324
# c4  -0.609930  0.080492 -0.128943  ... -0.177639 -0.463785  0.720235
# c5  -0.636441  0.114101 -0.119217  ... -0.123278 -0.511693  0.708468
# c6  -0.687514  0.083976 -0.132027  ... -0.254469 -0.487231  0.758775
# c7  -0.611495  0.103107 -0.137253  ... -0.142642 -0.503692  0.621675
# c8  -0.652149  0.104522 -0.128815  ... -0.191755 -0.488291  0.727268
# c9  -0.650664  0.117683 -0.115849  ... -0.294159 -0.454324  0.773938
# c10 -0.635275  0.103414 -0.129204  ... -0.222677 -0.512807  0.732656
# c11 -0.639309  0.087603 -0.128480  ... -0.178750 -0.487809  0.730299
# c12 -0.641633  0.092571 -0.134100  ... -0.248405 -0.442475  0.753625
# ...

# %%
mask = np.triu(np.ones_like(g_c_corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(0, 300, as_cmap=True)
sns.heatmap(g_c_corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.01, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# Analisando toda a saida de dados, somos capazes de perceber que existe correlação entre diversos elementos.

# %% [markdown]
# ### **Desafio 06:** Estudar o código que plota a matrix de correlação (heatmap).

# %% [markdown]
# **https://seaborn.pydata.org/generated/seaborn.heatmap.html**

# %% [markdown]
# ### **Desafio 07:** Resumo do que você aprendeu com os dados.

# %% [markdown]
# Utilizar novas funções tipo o pandas groupby e o crosstab, também aprendi a criar tabelas de comparação e utilizar funções para checar a correlação de elemntos.

# %% [markdown]
# # **Aula 4 - Merge e Análise de Resultados**

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[{'id','n_moa', 'ativo_moa'}], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  ativo_moa  n_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176       True      1
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      False      0
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931       True      3
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      False      0
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125       True      1
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g0', x='composto', hue='ativo_moa')

# %% [markdown]
# ## **Desafios aula 4**

# %% [markdown]
# ### **Desafio 01:** Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %% [markdown]
# Para resolver esse desafio usei como base o mesmo desafio do notebook do [@EloizioHMD](https://github.com/EloizioHMD/imersaodados3/blob/main/idd3_nb_d4.ipynb)

# %%
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %%
dados_resultados.drop(['id','n_moa', 'ativo_moa'], axis=1).sum()
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %%
# Separar as ocorrencias unicas do df dos Mecanismos de Ativacao (MoA).
# Dividindo o termo descritivo do MoA, separando o mecanismo da acao pelo '_'
split_moa = np.unique([col.split('_')[-1] for col in dados_resultados.drop(['id','n_moa', 'ativo_moa'],axis=1).columns])

# Gerador de frequencias dos MoA
frequencias = dados_resultados.drop(['id','n_moa', 'ativo_moa'], axis=1).sum()

# Gerador de contagem dos MoA
contadores = dict.fromkeys(split_moa , [0])
for name in frequencias.index:
  contadores[name.split('_')[-1]] += frequencias[name]

# Contagem dos MoA e apresentando o TOP 10
contagem_final = pd.DataFrame.from_dict(contadores).sum().sort_values(ascending=False).reset_index()
contagem_final.columns = ['acao', 'qtd']
contagem_10 = contagem_final.head(10)
contagem_10
# Out:
#                 acao   qtd
# 0          inhibitor  9693
# 1         antagonist  3449
# 2            agonist  2330
# 3            blocker   323
# 4              agent   150
# 5          activator   115
# 6              local    80
# 7  immunosuppressant    73
# 8  anti-inflammatory    73
# 9        antioxidant    73

# %%
# Criando a figura
fig, ax = plt.subplots(figsize = (12,8))

# Mudando o estilo de fundo
sns.set_style('darkgrid')

# Criando o gráfico 
sns.barplot(data=contagem_10, x='qtd', y='acao')

# Plotando as legendas e mudando o tamanho das fontes
fig.suptitle('TOP 10 AÇÕES DE MoA', fontsize=24, fontweight = 'bold')
ax.set_xlabel('Tipos de Ação',  fontsize=14, fontweight = 'bold')
ax.set_ylabel('Quantidade de Ação',  fontsize=14, fontweight = 'bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Inserção de valores na horizontal
# https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center') 

plt.show()

# %% [markdown]
# ###**Desafio 02:** Criar a coluna eh_controle para quando na linha tratamento == com_controle.

# %%
dados_combinados['eh_controle'] = (dados['tratamento'] == 'com_controle').astype(int)
dados_combinados.head()[['tratamento', 'eh_controle']]
# Out:
#   tratamento  eh_controle
# 0  com_droga            0
# 1  com_droga            0
# 2  com_droga            0
# 3  com_droga            0
# 4  com_droga            0

# %% [markdown]
# ###**Desafio 03:** Criar três colunas para indicar o tempo 24, 48, 72.

# %%
dados_combinados['24h'], dados_combinados['48h'], dados_combinados['72h'] = (dados_combinados['tempo'] == 24).astype(int), (dados_combinados['tempo'] == 48).astype(int), (dados_combinados['tempo'] == 72).astype(int)
dados_combinados.head()[['tempo', '24h', '48h', '72h']]
# Out:
#    tempo  24h  48h  72h
# 0     24    1    0    0
# 1     72    0    0    1
# 2     48    0    1    0
# 3     48    0    1    0
# 4     72    0    0    1

# %% [markdown]
# ###**Desafio 04:** Estudar sobre combinações de DF.

# %% [markdown]
# merge DataFrame ou objetos Series nomeados com uma join de estilo de banco de dados.
#
# A junção é feita em colunas ou índices. Se unir colunas em colunas, os índices DataFrame serão ignorados. Caso contrário, ao juntar índices em índices ou índices em uma coluna ou colunas, o índice será passado adiante. Ao realizar uma mesclagem cruzada, nenhuma especificação de coluna para mesclar é permitida.
#
# ####**Princípais parâmetros**
# DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#
# **right:** Df ou nome de série. O objeto que irá se fundir.
#
# **how:** {‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, O padrão é ‘inner’.
#
# Tipos de mesclagem e suas performace:
#
# >left: use apenas as chaves do quadro esquerdo, semelhante a uma junção externa esquerda SQL; preservar a ordem das chaves.
# right: use apenas as chaves do quadro direito, semelhante a uma junção externa direita SQL; preservar a ordem das chaves.
# outer: use a união de chaves de ambos os quadros, semelhante a uma junção externa completa SQL; classificar as chaves lexicograficamente.
# inner: usa a interseção de chaves de ambos os quadros, semelhante a uma junção interna SQL; preservar a ordem das teclas esquerdas.
# cross: cria o produto cartesiano de ambos os quadros, preserva a ordem das teclas à esquerda.

# %%
# Exemplo
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
print(df1)
print(df2)
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
# Mescle df1 e df2 nas colunas lkey e rkey.
#As colunas de valor têm os sufixos padrão, _x e _y, anexados.
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %% [markdown]
# ###**Desafio 05:** Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (escolher uma droga e comparar com controle).

# %%
## Análise de composto 9f80f3f77 (243 qtd) em relação a dose e tempo

composto = dados_combinados[dados_combinados['composto']=='9f80f3f77']
controle = dados_combinados.query('tratamento == "com_controle"')

fig, axes = plt.subplots(1,2,figsize=(20,8))

sns.boxplot(data=composto, y='g0', x='tempo', hue='dose',ax=axes[0])
axes[0].set_title('Composto 9f80f3f77')

sns.boxplot(data=controle, y='g0', x='tempo', hue='dose',ax=axes[1])
axes[1].set_title('Controle')

fig.suptitle('Análise de g0 com composto ou controle durante o tempo', fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ###**Desafio 06:** Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA.

# %%
compostos_ativos = (dados_combinados[['composto','ativo_moa']].query('ativo_moa == True'))
compostos_ativos
# Out:
#         composto  ativo_moa
# 0      b68db1d53       True
# 2      18bb41b2c       True
# 4      7cbed3131       True
# 5      e06749542       True
# 7      8b87a7a83       True
# ...          ...        ...
# 23807  a28556d51       True
# 23808  6c3a459be       True
# 23809  df1d0a5a1       True
# 23810  ecf3b6b74       True
# 23812  8b87a7a83       True
#
# [14447 rows x 2 columns]

# %%
compostos_nativos = (dados_combinados[['composto','ativo_moa']].query('ativo_moa == False'))
compostos_nativos
# Out:
#         composto  ativo_moa
# 1      df89a8e5a      False
# 3      8c7f86626      False
# 6      746ca1f5a      False
# 8      952b76dfc      False
# 14     e0cd5c091      False
# ...          ...        ...
# 23801  24c787f29      False
# 23804  74515bfd2      False
# 23806  47dd8f190      False
# 23811  cacb2b860      False
# 23813  972f41291      False
#
# [9367 rows x 2 columns]

# %% [markdown]
# ###**Desafio 07:** Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs difetentes.

# %%
(dados_combinados[['composto','n_moa']].query('n_moa > 1')).value_counts(ascending=False)
# Out:
# composto   n_moa
# 87d714366  2        718
# d50f18348  3        186
# 83a9ea167  2         18
# fe8625cad  4         12
# b30c11496  3         12
#                    ...
# f0d1b8dbc  2          1
# 1a038f0f7  2          1
# 4055d26a8  2          1
# c5ffd58ca  2          1
# 809527b9d  5          1
# Length: 172, dtype: int64

# %% [markdown]
# ###**Desafio 08:** Resumo do que eu aprendi com os dados.

# %% [markdown]
# Nessa aula pude aprender a mesclar colunas através da função .merge(), além de me aprofundar mais na criação de tabelas.

# %% [markdown]
# #**Aula 5 - Machine Learning, SCI-KIT Learning e desafios envolvidos**

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle  24h  48h  72h
# 0  id_000644bb2  com_droga     24   D1  ...           0    1    0    0
# 1  id_000779bfc  com_droga     72   D1  ...           0    0    0    1
# 2  id_000a6266a  com_droga     48   D1  ...           0    0    1    0
# 3  id_0015fd391  com_droga     48   D1  ...           0    0    1    0
# 4  id_001626bd3  com_droga     72   D2  ...           0    0    0    1
#
# [5 rows x 883 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=376)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth=3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree
fig, ax = plt.subplots(figsize=(15,10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,15):
    modelo_arvore = DecisionTreeClassifier(max_depth=i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6208272097417594,
#  0.6204073063195465,
#  0.6183077892084821,
#  0.6208272097417594,
#  0.6208272097417594,
#  0.6172580306529498,
#  0.6143187066974596,
#  0.6124291412975016,
#  0.5983623766533698,
#  0.6000419903422213,
#  0.5964728112534117]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7068395359823632,
#  0.7294630203138943,
#  0.7530838276205973,
#  0.776809616293108,
#  0.799223137893024]

# %%
sns.lineplot(x=range(1,15), y= teste, label='teste')
sns.lineplot(x=range(1,15), y= treino, label='treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6903212261179928

# %% [markdown]
# ##**Desafios Aula 5**

# %% [markdown]
# ###**Desafio 01:**Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %% [markdown]
# ###**Desafio 02:**Estde a documentação do Sklearn.

# %% [markdown]
# ###**Desafio 03:**Pesquisar por o fluxograma 'choosing the right estimator'.

# %% [markdown]
# ###**Desafio 04:**Teste outros problemas (pergunta). 0, 1 ou +.

# %% [markdown]
# ###**Desafio 05:**Escolha a droga mais utilizada e tente criar um modelo para prever esta label.

# %% [markdown]
# ###**Desafio 06:**O que eu aprendi com os dados.
